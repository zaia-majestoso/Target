# %% [markdown]
# <a href="https://colab.research.google.com/github/zaia-majestoso/trab/blob/main/juro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time


#emprestimo
emp1 = 10000
anos = 8


print("valor inicial: ",10000)
start = time.time_ns()
for i in range (1, 200):
  emp1 += emp1 * 0.03
  print(f"f{i} = ", emp1)
print('tempo decorrido: ',start)
# Out:
# valor inicial:  10000
# f1 =  10300.0
# f2 =  10609.0
# f3 =  10927.27
# f4 =  11255.0881
# f5 =  11592.740743
# f6 =  11940.52296529
# f7 =  12298.7386542487
# f8 =  12667.700813876161
# f9 =  13047.731838292446
# f10 =  13439.16379344122
# f11 =  13842.338707244457
# f12 =  14257.60886846179
# f13 =  14685.337134515643
# f14 =  15125.897248551111
# f15 =  15579.674166007644
# f16 =  16047.064390987873
# f17 =  16528.47632271751
# f18 =  17024.330612399037
# f19 =  17535.060530771007
# f20 =  18061.112346694135
# f21 =  18602.94571709496
# f22 =  19161.03408860781
# f23 =  19735.86511126604
# f24 =  20327.941064604023
# f25 =  20937.779296542143
# f26 =  21565.91267543841
# f27 =  22212.890055701562
# f28 =  22879.27675737261
# f29 =  23565.655060093788
# f30 =  24272.624711896602
# f31 =  25000.8034532535
# f32 =  25750.8275568511
# f33 =  26523.352383556634
# f34 =  27319.052955063333
# f35 =  28138.624543715232
# f36 =  28982.783280026688
# f37 =  29852.26677842749
# ...
