# %% [markdown]
# <a href="https://colab.research.google.com/github/zaia-majestoso/trab/blob/main/TPG1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Vinicius Zaia, Franklin Jeronimo, Eduardo Neves, Caike Azevedo
# #BCC 3B

# %%
import numpy as np
import sympy as sp
import math
import matplotlib.pyplot as plt
from IPython.display import display, Math
from fractions import Fraction

# %%
#Ex 1
#set symbols and equations
x1 =sp.Symbol("x")
y2 = (x1**2 - 4)/(x1 - 2)
x = np.linspace(-10,10,10)
y = (x**2 - 4)/(x - 2)
lim_3 = sp.limit(y2,x1,3)
lim_0 = sp.limit(y2,x1,0)

#passo a passo
display(Math(r"\lim{x \to 3} f(x) = " + f"{y2}"))
display(Math(r"\lim{x \to 3} f(x) = " + f"{y2.subs(x1,3)}"))

#plot
plt.plot(x,y)
plt.plot(3,5,"o",color="red",label = "Limite esquerdo e direito")
plt.title(r'$\mathrm{Gráfico\ de}\ f(x) = \frac{x^2 - 4}{x - 2}$')
plt.legend()
plt.text(2,5.5,"$(3,5)$")
# Out:
# $\displaystyle \lim{x \to 3} f(x) = (x**2 - 4)/(x - 2)$
# $\displaystyle \lim{x \to 3} f(x) = 5$
# Text(2, 5.5, '$(3,5)$')

# %%
#setup de funcoes
x = sp.symbols('x')
f_x = (x**2 - 3 * x + 2 )/(x - 1)
f_x_1 = sp.factor((x**2 - 3*x + 2))
f_x_2 = sp.factor((x**2 - 3*x + 2)/(x - 1))

#2 a)
print("a)")
display(Math(r"$\lim_{x \to 1} f(x) = \frac{x^2 - 3x + 2}{x - 1}$"))
print("\n")
display(Math(r'$\lim_{x \to 1} f(x) = \frac{(x - 2)*(x - 1)}{x - 1}$'))
print("\n")
display(Math(r"$\lim_{x \to 1}f(x) = {(x - 2)}$" ))
limite = sp.limit(f_x_2, x, 1)
print("\n")
display(Math(r"$\lim_{x \to 1}f(x) = {(-1)}$" ))
print("\n")

#plot
xp = np.linspace(-10,10,200)
f_x = (xp**2 - 3 * xp + 2 )/(xp - 1)
plt.plot(xp,f_x)
plt.plot(1,-1,"o",color="red",label="Limite")
plt.legend()
plt.show()
# Out:
# a)
# $\displaystyle \lim_{x \to 1} f(x) = \frac{x^2 - 3x + 2}{x - 1}$
# $\displaystyle \lim_{x \to 1} f(x) = \frac{(x - 2)*(x - 1)}{x - 1}$
# $\displaystyle \lim_{x \to 1}f(x) = {(x - 2)}$
# $\displaystyle \lim_{x \to 1}f(x) = {(-1)}$

# %%
#b)
print("b)")
x = sp.symbols('x')
f_x = (3*(x**2) - 2 * x - 5 ) / (x - 1)
f_x_1 = sp.factor((3*(x**2) - 2 * x - 5 ))
f_x_2 = sp.factor((3*(x**2) - 2 * x - 5 )/(x - 1))

#passo a passo
display(Math(r"$\lim_{x \to 2} f(x) = \frac{3x^2 - 2x - 5}{x - 1}$"))
print("\n")
display(Math(r"$\lim_{x \to 2} f(x) = \frac{(x + 1) * (3x - 5)}{x - 1}$"))
limite = sp.limit(f_x_2, x, 2)
print("\n")
display(Math(r"\lim_{x \to 2} f(x) = "+ f"{limite}"))
print("\n")

#plot
xp = np.linspace(-10,10,200)
f_x = (3*(xp**2) - 2 * xp - 5 ) / (xp - 1)
plt.plot(xp,f_x)
plt.plot(2,3,"o",color="red",label="Limite")
plt.legend()
plt.show()
# Out:
# b)
# $\displaystyle \lim_{x \to 2} f(x) = \frac{3x^2 - 2x - 5}{x - 1}$
# $\displaystyle \lim_{x \to 2} f(x) = \frac{(x + 1) * (3x - 5)}{x - 1}$
# $\displaystyle \lim_{x \to 2} f(x) = 3$

# %%
#ex 3
#a)
print("a)")
x = sp.symbols('x')
f_x = sp.sqrt(x)-3 / (x-9) 
f_x_1 = sp.factor(sp.sqrt(x) - 3 / (x-9)) 
fx = sp.sqrt(x - 8) + 3

#passo a passo
display(Math(r"$\lim_{x \to 9} f(x) = {\sqrt{x - 8} + 3 }$"))
print("\n")
display(Math(r"$\lim_{x \to 9} f(x) = {\sqrt{9 - 8} + 3 }$"))
print("\n")
display(Math(r"$\lim_{x \to 9} f(x) = {1 + 3}$"))
print("\n")
limite = sp.limit(fx, x, 9)
display(Math(r"\lim_{x \to 9} f(x) = " + f"{limite}"))
print("\n")

#plot
xp = np.linspace(8,20,200)
y = sp.sqrt(x - 8) + 3
y_vals = np.array([sp.N(y.subs(x, val)) for val in xp])

plt.plot(xp, y_vals)
plt.plot(9,4,"o",color="red",label="Limite")
plt.legend()
plt.show()
# Out:
# a)
# $\displaystyle \lim_{x \to 9} f(x) = {\sqrt{x - 8} + 3 }$
# $\displaystyle \lim_{x \to 9} f(x) = {\sqrt{9 - 8} + 3 }$
# $\displaystyle \lim_{x \to 9} f(x) = {1 + 3}$
# $\displaystyle \lim_{x \to 9} f(x) = 4$

# %%
#b)
print("b)")

#passo a passo
display(Math(r"$\lim_{x \to 9} f(x) = \frac{\sqrt{x} - 3}{x - 9}$"))
print("\n")
display(Math(r"$\lim_{x \to 9} f(x) = \frac{(\sqrt{x} - 3) * (\sqrt{x} + 3)}{(x - 9) * (\sqrt{x} + 3)}$"))
print("\n")
display(Math(r"$\lim_{x \to 9} f(x) = \frac{x - 9 }{(x - 9) * (\sqrt{x} + 3)}$"))
print("\n")
display(Math(r"$\lim_{x \to 9} f(x) = \frac{1 }{(\sqrt{x} + 3)}$"))
print("\n")
display(Math(r"\lim_{x \to 9} f(x) = "+f"{limite}"))
print("\n")

#equations
f_x_1 = 1/(sp.sqrt(x) + 3)
limite = sp.limit(f_x_1, x, 9)

#plot
x2 = np.linspace(7.2,10.8,200)
y_vals2 = np.array([sp.N(f_x_1.subs(x, val)) for val in x2])
plt.plot(x2,y_vals2)
plt.plot(9,1/6,"o",color="red",label="Limite")
plt.legend()
plt.show()
# Out:
# b)
# $\displaystyle \lim_{x \to 9} f(x) = \frac{\sqrt{x} - 3}{x - 9}$
# $\displaystyle \lim_{x \to 9} f(x) = \frac{(\sqrt{x} - 3) * (\sqrt{x} + 3)}{(x - 9) * (\sqrt{x} + 3)}$
# $\displaystyle \lim_{x \to 9} f(x) = \frac{x - 9 }{(x - 9) * (\sqrt{x} + 3)}$
# $\displaystyle \lim_{x \to 9} f(x) = \frac{1 }{(\sqrt{x} + 3)}$
# $\displaystyle \lim_{x \to 9} f(x) = 4$

# %%
#c)
print("c)")

#symbols and equations
x = sp.Symbol('x')
f = (2*(x**2) - 5*x + 3)/(2*(x**2) - 3*x)
ff = sp.factor(f)
f_subs = f.subs(x, sp.Rational(3, 2))


#passo a passo
display(Math(r"$\lim_{x \to 3/2} f(x) = \frac{2x^2 - 5x + 3}{2x^2 - 3x}$"))
print("\n")
display(Math(r"$\lim_{x \to 3/2} f(x) = \frac{(2x -3)(x-1)}{x(2x -3)}$"))
print("\n")
display(Math(r"$\lim_{x \to 3/2} f(x) = \frac{(x-1)}{x}$"))
print("\n")
display(Math(r"\lim_{x \to 3/2} f(x) = \frac{(\frac{3}{2}-1)}{\frac{3}{2}} "))
print("\n")
display(Math(r"\lim_{x \to 3/2} f(x) = \frac{1}{2}*\frac{2}{3} "))
print("\n")
display(Math(r"\lim_{x \to 3/2} f(x) =\frac{1}{3} "))
print("\n")

#plot
x3 = np.linspace(-10,10,1000)
y_vals2 = np.array([sp.N(f.subs(x, val)) for val in x3])
plt.plot(x3,y_vals2)
plt.plot(2/3,1/3,"o",color ="red",label="Limite")
plt.legend()
plt.show()
# Out:
# c)
# $\displaystyle \lim_{x \to 3/2} f(x) = \frac{2x^2 - 5x + 3}{2x^2 - 3x}$
# $\displaystyle \lim_{x \to 3/2} f(x) = \frac{(2x -3)(x-1)}{x(2x -3)}$
# $\displaystyle \lim_{x \to 3/2} f(x) = \frac{(x-1)}{x}$
# $\displaystyle \lim_{x \to 3/2} f(x) = \frac{(\frac{3}{2}-1)}{\frac{3}{2}} $
# $\displaystyle \lim_{x \to 3/2} f(x) = \frac{1}{2}*\frac{2}{3} $
# $\displaystyle \lim_{x \to 3/2} f(x) =\frac{1}{3} $

# %%
#d)
print("d)")
#equations
x = sp.Symbol('x')
g = (x**2) + 3
limit = sp.limit(g,x,-3)

#passo a passo
display(Math(r"$\lim_{x \to -3} g(x) = {x^2 + 3}$"))
print("\n")
display(Math(r"$\lim_{x \to -3} g(x) = {9 + 3}$"))
print("\n")
display(Math(r"\lim_{x \to -3} g(x) = "+f"{limit}"))

#plot
x4 = np.linspace(0,20,200)
y_vals3 = np.array([sp.N(g.subs(x, val)) for val in x4])
plt.plot(x4,y_vals3)
plt.plot(3,12,"o",color="red",label="Limite")
plt.legend()
plt.show()
# Out:
# d)
# $\displaystyle \lim_{x \to -3} g(x) = {x^2 + 3}$
# $\displaystyle \lim_{x \to -3} g(x) = {9 + 3}$
# $\displaystyle \lim_{x \to -3} g(x) = 12$

# %%
# ex 4

#a)
print("a) \n")
x = sp.Symbol("x")
fx = (x - 3 )/ (7 -x) 

#plotando a função
xp = np.linspace(-10,10,200)
yp = (xp - 3 )/ (7 -xp)
plt.plot(xp,yp)
plt.xlabel('$x$')
plt.ylabel("$f(x)$")
plt.title(r"$f(x) = \frac{x - 3}{7 - x}$")

display(Math(r"$\lim{x \to \infty} f(x) = \frac{x - 3}{7 - x}$"))
print("\n")
display(Math(r"$\lim{x \to \infty} f(x) = \frac{1 - \frac{3}{x}}{\frac{7}{x} - 1}$"))
print("\n")
display(Math(r"$\lim{x \to \infty} f(x) = \frac{1 - 0}{0 - 1}$"))
print("\n")
display(Math(r"$\lim{x \to \infty} f(x) = \frac{1}{- 1}$"))
print("\n")
display(Math(r"$\lim{x \to \infty} f(x) = -1$"))
print("\n")
# Out:
# a)
# $\displaystyle \lim{x \to \infty} f(x) = \frac{x - 3}{7 - x}$
# $\displaystyle \lim{x \to \infty} f(x) = \frac{1 - \frac{3}{x}}{\frac{7}{x} - 1}$
# $\displaystyle \lim{x \to \infty} f(x) = \frac{1 - 0}{0 - 1}$
# $\displaystyle \lim{x \to \infty} f(x) = \frac{1}{- 1}$
# $\displaystyle \lim{x \to \infty} f(x) = -1$

# %%
#b)
print("b) \n")
#Descobrindo o resultado do limite
x = sp.Symbol("x")
fx = 1/(x**2 + 5*x)
limit = sp.limit(fx,x,np.infty)

#fazendo o passo a passo
display(Math(r"$\lim{x \to \infty} f(x) = \frac{1}{x^2 + 5x}$"))
print("\n")
display(Math(r"$\lim{x \to \infty} f(x) = \frac{1}{\lim_{x \to \infty}(x(x + 5))}$"))
print("\n")
display(Math(r"$\lim{x \to \infty} f(x) = \frac{1}{\infty}$"))
print("\n")
display(Math(r"\lim{x \to \infty} f(x) ="+f"{limit}"))
print("\n")

#Grafico
xp = np.linspace(-10,10,100)
yp = (1/(xp**2 + 5*xp))

plt.plot(xp,yp)
plt.title(r"$f(x) = \frac{1}{x^2 + 5x}$")
plt.xlabel("$x$")
plt.ylabel("$f(x)$")
# Out:
# b)
# $\displaystyle \lim{x \to \infty} f(x) = \frac{1}{x^2 + 5x}$
# $\displaystyle \lim{x \to \infty} f(x) = \frac{1}{\lim_{x \to \infty}(x(x + 5))}$
# $\displaystyle \lim{x \to \infty} f(x) = \frac{1}{\infty}$
# $\displaystyle \lim{x \to \infty} f(x) =0$
# Text(0, 0.5, '$f(x)$')

# %%
#c)
print("c) \n")
#Descobrindo o resultado do limite
x = sp.Symbol("x")
fx = (x -1) /(x**2 + 5*x - 6)
limit = sp.limit(fx,x,np.infty)
fact = sp.factor(x**2 +5*x - 6)

#passo a passo
display(Math(r"$\lim{x \to \infty} f(x) = \frac{x-1}{x^2 + 5x - 6}$"))
print("\n")
display(Math(r"$\lim{x \to \infty} f(x) = \frac{\lim_{x \to \infty}(x-1)}{\lim_{x \to \infty}(x^2 + 5x - 6)}$"))
print("\n")
display(Math(r"$\lim{x \to \infty} f(x) = \frac{\lim_{x \to \infty}(x-1)}{\lim_{x \to \infty}((x-1)(x+6))}$"))
print("\n")
display(Math(r"$\lim{x \to \infty} f(x) = \frac{1}{\lim_{x \to \infty}(x+6)}$"))
print("\n")
display(Math(r"$\lim{x \to \infty} f(x) = \frac{1}{\infty}$"))
print("\n")
display(Math(r"\lim{x \to \infty} f(x) = "+f"{limit}"))

#Grafico
xp = np.linspace(-10,10,100)
yp = ((xp-1)/(xp**2 + 5*xp - 6))

plt.plot(xp,yp)
plt.title(r"$f(x) = \frac{x-1}{x^2 + 5x-6}$")
plt.xlabel("$x$")
plt.ylabel("$f(x)$")
# Out:
# c)
# $\displaystyle \lim{x \to \infty} f(x) = \frac{x-1}{x^2 + 5x - 6}$
# $\displaystyle \lim{x \to \infty} f(x) = \frac{\lim_{x \to \infty}(x-1)}{\lim_{x \to \infty}(x^2 + 5x - 6)}$
# $\displaystyle \lim{x \to \infty} f(x) = \frac{\lim_{x \to \infty}(x-1)}{\lim_{x \to \infty}((x-1)(x+6))}$
# $\displaystyle \lim{x \to \infty} f(x) = \frac{1}{\lim_{x \to \infty}(x+6)}$
# $\displaystyle \lim{x \to \infty} f(x) = \frac{1}{\infty}$
# $\displaystyle \lim{x \to \infty} f(x) = 0$
# Text(0, 0.5, '$f(x)$')

# %%
#d)
print("d) \n")
#Descobrindo o resultado do limite
x = sp.Symbol("x")
fx = (3 + x) /(x**2 - 2)
limit = sp.limit(fx,x,np.infty)


#passo a passo
display(Math(r"$\lim{x \to \infty} f(x) = \frac{3 + x}{x^2 - 2}$"))
print("\n")
display(Math(r"$\lim{x \to \infty} f(x) = \frac{\frac{3}{x^2} +\frac {x}{x^2}}{\frac{x^2}{x^2} - \frac{2}{x^2}}$"))
print("\n")
display(Math(r"$\lim{x \to \infty} f(x) = \frac{\lim_{x \to \infty}(\frac{3}{x^2} +\frac {x}{x^2})}{\lim_{x \to \infty}(1 - \frac{2}{x^2})}$"))
print("\n")
display(Math(r"$\lim{x \to \infty} f(x) = \frac{\lim_{x \to \infty}(0 + 0)} {\lim_{x \to \infty}(1 - 0)}$"))
print("\n")
display(Math(r"$\lim{x \to \infty} f(x) = \frac{0} {1}$"))
print("\n")
display(Math(r"\lim{x \to \infty} f(x) = "+f"{limit}"))
print("\n")


#Grafico
xp = np.linspace(-10,10,200)
yp = ((3 + xp)/(xp**2 - 2))

plt.plot(xp,yp)
plt.title(r"$f(x) = \frac{3+x}{x^2 - 2}$")
plt.xlabel("$x$")
plt.ylabel("$f(x)$")
# Out:
# d)
# $\displaystyle \lim{x \to \infty} f(x) = \frac{3 + x}{x^2 - 2}$
# $\displaystyle \lim{x \to \infty} f(x) = \frac{\frac{3}{x^2} +\frac {x}{x^2}}{\frac{x^2}{x^2} - \frac{2}{x^2}}$
# $\displaystyle \lim{x \to \infty} f(x) = \frac{\lim_{x \to \infty}(\frac{3}{x^2} +\frac {x}{x^2})}{\lim_{x \to \infty}(1 - \frac{2}{x^2})}$
# $\displaystyle \lim{x \to \infty} f(x) = \frac{\lim_{x \to \infty}(0 + 0)} {\lim_{x \to \infty}(1 - 0)}$
# $\displaystyle \lim{x \to \infty} f(x) = \frac{0} {1}$
# $\displaystyle \lim{x \to \infty} f(x) = 0$
# Text(0, 0.5, '$f(x)$')
